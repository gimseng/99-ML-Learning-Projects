# %% [markdown]
# ## Face Detection with Haar Cascades

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
driver = cv2.imread('../Data/man-driving-3.jpg',0)

# %%
driver
# Out:
# array([[255, 255, 255, ..., 133, 133, 140],
#        [255, 255, 255, ..., 130, 125, 129],
#        [255, 255, 255, ..., 102, 108, 108],
#        ...,
#        [ 85,  84,  83, ...,  68,  70,  80],
#        [ 79,  79,  78, ...,  51,  53,  61],
#        [ 75,  75,  75, ...,  37,  44,  49]], dtype=uint8)

# %%
plt.imshow(driver,cmap='gray')

# %% [markdown]
# ## Cascade Files
#
# OpenCV comes with these pre-trained cascade files,https://github.com/opencv/opencv/tree/master/data/haarcascades, download for here

# %%
face_cascade = cv2.CascadeClassifier('../Data/haarcascade_frontalface_default.xml')

# %% [markdown]
# ## Face Detection

# %%
def detect_face(img):
    
  
    face_img = img.copy()
  
    face_rects = face_cascade.detectMultiScale(face_img) 
    
    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
result = detect_face(driver)

# %%
plt.imshow(result,cmap='gray')

# %% [markdown]
# ## video capturing

# %%
cap = cv2.VideoCapture(0) 

while True: 
    
    ret, frame = cap.read(0) 
     
    frame = detect_face(frame)
 
    cv2.imshow('Video Face Detection', frame) 
 
    c = cv2.waitKey(1) 
    if c == 27: 
        break 
    #press esc key to exit
    
cap.release() 
cv2.destroyAllWindows()
